# %% [markdown]
# # Scraping Twitter Data
#
# 1. creating developer account
#
# 2. introduction to main functions of Twitter API - json structure of a file + Tweepy
#
# 3. making queries
#
# 4. downloading user timeline - last 3200 users
#
# 5. streaming
#
# 6. let's analyze the json data

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from collections import Counter
# from config import *

# %% [markdown]
# # 1. Developer account
#
# **1st step** First of all, let's create a Twitter account and then go to the developer website at the link
#
# https://developer.twitter.com/en/apps
#
# **2nd step** Then we click on **Create an app**
#
# ![alt-text-1](imgs/create-app.png "title-1")
#
# **3rd step** We need to fill the form with some basic informations as shown below
#
# ![alt-text-1](imgs/top.png "Top-page") ![alt-text-2](imgs/bottom.png "Bottom-page")
#
# **4th step** We need to copy and paste below the token and consumer keys (click on *Generate*)
#
# ![alt-text-1](imgs/access-token.png "title-1")

# %%
# download tweepy

## access token informations 
access_token1 = "3335224786-nw1ag61Z4lACO2pNoVUE2aECs87ilYTYRCuqNsQ"
access_token_secret1 = "r108kRImaqrUTKozq96NrSL9w9hzFegYybgTg6Y9TPXV1"

consumer_key1 = "RMlzbdrEX8wY87WI9OFLv2BX9"
consumer_secret1 = "K04A0G7sQrAIkIFc5BrQcUEufhPmLAQFlELSjJ1iTh0PrSXZBl"

# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import API
from tweepy import Cursor
import json
import datetime

# %%
auth = OAuthHandler(consumer_key1, consumer_secret1)
auth.set_access_token(access_token1, access_token_secret1)
api = API(auth_handler=auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# # 2. Introduction to main functions of Twitter API + Tweepy
#
# **What is Twitter**
#
# It is an online social network, which allows users to post short messages/status, 280-character each tweets. Because of the continous flood of tweets generated everyday, Twitter is a great source to get rapid and current information through the web. It can be particularly useful to understand how people interacts with respect a specific (current) topic, how they discuss and create conversations (e.g. threads) or just to keep yourself posted about what's happening around the world.
#
# **Why Twitter for scraping data**
#
# In the last years, with the limitations imposed by law restrictions, accessing social media data through scraping is becoming a challenging task. Nevertheless, Twitter remains (with Reddit) one of the few that is still accessible and relatively open to do research studies and analyze aggregated social network data.
#
# **Main functionalities of the Twitter API**
#
# Through the Twitter API, any developer can access in several ways Twitter data. It's possible to retrieve users timeline (all the last 3200 tweets posted by a single user), it's possible to collect conversation around a topic, up to 7 days before and, as main functionality, it's possible to track the live stream of information related to a specific topic (which can be easily tracked through hashtags).
#
#
# **Python library Tweepy**
#
# Tweepy is a popular Python library that helps us to play with Twitter API.
#
# **Some practical examples of studies performed using Twitter Data**
#
# Here some studies performed analyzing Twitter Data:
# - [Quantifying Controversy in Social Media](https://arxiv.org/abs/1507.05224)
# - [Falling into the Echo Chamber: The Italian Vaccination Debate on Twitter](https://ojs.aaai.org//index.php/ICWSM/article/view/7285)
# - [Communication Dynamics in Twitter During Political
# Campaigns: The Case of the 2011 Spanish National
# Election](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.701.4830&rep=rep1&type=pdf)

# %% [markdown]
# # 3. Downloading user timeline
#
# Analysis of user json and explaining the main limitation (3200 users)
#
#
#
# Reference: https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline
#
# ```:allowed_param: 'id', 'user_id', 'screen_name', 'since_id', 'max_id', 'count', 'include_rts', 'trim_user', 'exclude_replies'```

# %%
user_timeline = api.user_timeline(
    screen_name="fra_fabbri", # you can user user_id or id too
    count=200, # 200 is the max-value
    include_rts = True, # include also retweeted status
)

# %%
print("Numer of tweets")
print(len(user_timeline))
# Out:
# Numer of tweets
# 199

# %%
for k in user_timeline[0]._json["user"]:
    print(k)
    print(user_timeline[0]._json["user"][k])
    print()
# Out:
# id
# 1524907406
#
# id_str
# 1524907406
#
# name
# Francesco Fabbri
#
# screen_name
# Fra_Fabbri
#
# location
# Barcellona, Spagna
#
# description
# Ph.D. Student at @DTIC_UPF | @WSSC_UPF  | @eurecat_news | Mainly interested in Algorithmic Fairness | ex-@picampusschool scholar
#
# url
# https://t.co/UaMic2k7ed
#
# entities
# {'url': {'urls': [{'url': 'https://t.co/UaMic2k7ed', 'expanded_url': 'http://frafabbri.github.io', 'display_url': 'frafabbri.github.io', 'indices': [0, 23]}]}, 'description': {'urls': []}}
#
# protected
# False
#
# followers_count
# 198
#
# friends_count
# 873
#
# listed_count
# 3
#
# created_at
# Mon Jun 17 13:51:31 +0000 2013
#
# favourites_count
# 1614
#
# utc_offset
# None
#
# time_zone
# None
#
# geo_enabled
# False
#
# verified
# False
#
# statuses_count
# 153
#
# lang
# None
#
# contributors_enabled
# False
#
# is_translator
# False
#
# is_translation_enabled
# False
#
# profile_background_color
# C0DEED
#
# profile_background_image_url
# http://abs.twimg.com/images/themes/theme1/bg.png
#
# profile_background_image_url_https
# https://abs.twimg.com/images/themes/theme1/bg.png
#
# profile_background_tile
# False
#
# profile_image_url
# http://pbs.twimg.com/profile_images/1054644791919763456/QFT3ljTd_normal.jpg
#
# profile_image_url_https
# https://pbs.twimg.com/profile_images/1054644791919763456/QFT3ljTd_normal.jpg
#
# profile_link_color
# 1DA1F2
#
# profile_sidebar_border_color
# C0DEED
#
# profile_sidebar_fill_color
# DDEEF6
#
# profile_text_color
# 333333
#
# profile_use_background_image
# True
#
# has_extended_profile
# False
#
# default_profile
# True
#
# default_profile_image
# False
#
# following
# False
#
# follow_request_sent
# False
#
# notifications
# False
#
# translator_type
# none

# %% [markdown]
# **So we get only the last 200? What about all the other tweets?**
#
# With the Standard Twitter API we can get up to the last 3200 tweets. If we want more, we have to get premium account, which is quite expensive. In our case we don't really need it, because we mainly work with streaming data, which produces good amount of data in relative short amount of time.
#
# **But... How do we get the 3200 tweets for one user?**
#
# It's possible to retrieve the last tweets of all the public users (private ones we can't). In the following example we will go through the last 3200 tweets of World Health Organization (@WHO).
#
#
# Reference: http://docs.tweepy.org/en/latest/cursor_tutorial.html

# %%
all_pages = []
for page in Cursor(api.user_timeline, screen_name="@WHO", count=3200, tweet_mode="extended").pages():
    all_pages +=page
    print(len(all_pages))
# Out:
# 200
# 400
# 598
# 797
# 997
# 1197
# 1397
# 1597
# 1797
# 1993
# 2192
# 2391
# 2590
# 2790
# 2988
# 3187
# 3235

# %%
t = all_pages[1]
t._json
# Out:
# {'created_at': 'Sun Dec 06 06:22:58 +0000 2020',
#  'id': 1335469766308466688,
#  'id_str': '1335469766308466688',
#  'full_text': 'RT @Jim_Jordan: Durham confirms what we already knew. \n\nJames Comey’s FBI was out to get President Trump.',
#  'truncated': False,
#  'display_text_range': [0, 105],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Jim_Jordan',
#     'name': 'Rep. Jim Jordan',
#     'id': 18166778,
#     'id_str': '18166778',
#     'indices': [3, 14]}],
#   'urls': []},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 25073877,
#   'id_str': '25073877',
#   'name': 'Donald J. Trump',
#   'screen_name': 'realDonaldTrump',
#   'location': 'Washington, DC',
#   'description': '45th President of the United States of America🇺🇸',
#   'url': 'https://t.co/8f9VFxztEJ',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#       'expanded_url': 'http://Vote.DonaldJTrump.com',
#       'display_url': 'Vote.DonaldJTrump.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 88720650,
#   'friends_count': 51,
#   'listed_count': 125669,
#   'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#   'favourites_count': 6,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 58986,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '6D5C18',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': 'BDDCAD',
#   'profile_sidebar_fill_color': 'C5CEC0',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': True,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sat Dec 05 16:24:53 +0000 2020',
#   'id': 1335258853412319234,
#   'id_str': '1335258853412319234',
#   'full_text': 'Durham confirms what we already knew. \n\nJames Comey’s FBI was out to get President Trump. https://t.co/6DNJcxLT4E',
#   'truncated': False,
#   'display_text_range': [0, 89],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/6DNJcxLT4E',
#      'expanded_url': 'https://twitter.com/cbs_herridge/status/1334976850490257412',
#      'display_url': 'twitter.com/cbs_herridge/s…',
#      'indices': [90, 113]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 18166778,
#    'id_str': '18166778',
#    'name': 'Rep. Jim Jordan',
#    'screen_name': 'Jim_Jordan',
#    'location': 'Washington, D.C. ',
#    'description': "Proudly serving Ohio's beautiful Fourth District. Ranking Member on @JudiciaryGOP. Fighting to #DoWhatWeSaid",
#    'url': 'https://t.co/wd2j7YpRZm',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/wd2j7YpRZm',
#        'expanded_url': 'http://jordan.house.gov/',
#        'display_url': 'jordan.house.gov',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1951737,
#    'friends_count': 3998,
#    'listed_count': 6588,
#    'created_at': 'Tue Dec 16 17:20:24 +0000 2008',
#    'favourites_count': 2534,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 4639,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/596012379231617025/TtrAXbnA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/596012379231617025/TtrAXbnA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18166778/1406042839',
#    'profile_link_color': '4F90DB',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'BA0D1F',
#    'profile_text_color': '01050D',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1334976850490257412,
#   'quoted_status_id_str': '1334976850490257412',
#   'quoted_status_permalink': {'url': 'https://t.co/6DNJcxLT4E',
#    'expanded': 'https://twitter.com/cbs_herridge/status/1334976850490257412',
#    'display': 'twitter.com/cbs_herridge/s…'},
#   'quoted_status': {'created_at': 'Fri Dec 04 21:44:18 +0000 2020',
#    'id': 1334976850490257412,
#    'id_str': '1334976850490257412',
#    'full_text': 'NEW #Durham Special Counsel Durham writes "political or personal bias may have motivated or contributed" to actions of former FBI lawyer who altered CIA email to renew 2017 surveillance @carterwpage Durham seeks jail time for Kevin Clinesmith who altered to falsely state former https://t.co/VHa5mO14FN',
#    'truncated': False,
#    'display_text_range': [0, 278],
#    'entities': {'hashtags': [{'text': 'Durham', 'indices': [4, 11]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'carterwpage',
#       'name': 'Carter Page, Ph.D.',
#       'id': 261256582,
#       'id_str': '261256582',
#       'indices': [186, 198]}],
#     'urls': [],
#     'media': [{'id': 1334976847256358917,
#       'id_str': '1334976847256358917',
#       'indices': [279, 302],
#       'media_url': 'http://pbs.twimg.com/media/EobKXpwWEAUJs58.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EobKXpwWEAUJs58.jpg',
#       'url': 'https://t.co/VHa5mO14FN',
#       'display_url': 'pic.twitter.com/VHa5mO14FN',
#       'expanded_url': 'https://twitter.com/CBS_Herridge/status/1334976850490257412/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 554, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 750, 'h': 1624, 'resize': 'fit'},
#        'small': {'w': 314, 'h': 680, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1334976847256358917,
#       'id_str': '1334976847256358917',
#       'indices': [279, 302],
#       'media_url': 'http://pbs.twimg.com/media/EobKXpwWEAUJs58.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EobKXpwWEAUJs58.jpg',
#       'url': 'https://t.co/VHa5mO14FN',
#       'display_url': 'pic.twitter.com/VHa5mO14FN',
#       'expanded_url': 'https://twitter.com/CBS_Herridge/status/1334976850490257412/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 554, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 750, 'h': 1624, 'resize': 'fit'},
#        'small': {'w': 314, 'h': 680, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1196441152486072320,
#     'id_str': '1196441152486072320',
#     'name': 'Catherine Herridge',
#     'screen_name': 'CBS_Herridge',
#     'location': 'Washington, D.C.',
#     'description': '@CBSNews Senior Investigative Correspondent, military mom, organ donor. Covering national security and intel. Follow me for more news, less noise #factsmatter',
#     'url': 'https://t.co/5Gq67gTp7W',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5Gq67gTp7W',
#         'expanded_url': 'https://www.viacomcbspressexpress.com/cbs-news/shows/cbs-news/bios?id=catherine-herridge',
#         'display_url': 'viacomcbspressexpress.com/cbs-news/shows…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 461032,
#     'friends_count': 21,
#     'listed_count': 1897,
#     'created_at': 'Mon Nov 18 14:53:25 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 1440,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1196446872371642369/J4nMFPJv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1196446872371642369/J4nMFPJv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196441152486072320/1574089953',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 5243,
#    'favorite_count': 11728,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 11368,
#   'favorite_count': 37026,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': True,
#  'quoted_status_id': 1334976850490257412,
#  'quoted_status_id_str': '1334976850490257412',
#  'quoted_status_permalink': {'url': 'https://t.co/6DNJcxLT4E',
#   'expanded': 'https://twitter.com/cbs_herridge/status/1334976850490257412',
#   'display': 'twitter.com/cbs_herridge/s…'},
#  'retweet_count': 11368,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
t = all_pages[0]
t._json['retweeted_status']
# Out:
# {'created_at': 'Fri Dec 04 00:05:16 +0000 2020',
#  'id': 1334649938932879363,
#  'id_str': '1334649938932879363',
#  'full_text': '🔥🔥🔥\n\n"Ossoff is a baby-faced trust fund socialist who will be a Schumer puppet. Raphael Warnock is a Jeremiah Wright loving gun-grabber." \n\n-@JesseBWatters on the Georgia run-offs. #GAsen #GApol https://t.co/4TVMCFsoVn',
#  'truncated': False,
#  'display_text_range': [0, 194],
#  'entities': {'hashtags': [{'text': 'GAsen', 'indices': [181, 187]},
#    {'text': 'GApol', 'indices': [188, 194]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JesseBWatters',
#     'name': 'Jesse Watters',
#     'id': 56561449,
#     'id_str': '56561449',
#     'indices': [141, 155]}],
#   'urls': [],
#   'media': [{'id': 1334649486342320128,
#     'id_str': '1334649486342320128',
#     'indices': [195, 218],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1334649486342320128/pu/img/5wj6eDq3xU2uH99R.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1334649486342320128/pu/img/5wj6eDq3xU2uH99R.jpg',
#     'url': 'https://t.co/4TVMCFsoVn',
#     'display_url': 'pic.twitter.com/4TVMCFsoVn',
#     'expanded_url': 'https://twitter.com/mattdizwhitlock/status/1334649938932879363/video/1',
#     'type': 'photo',
#     'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 640, 'h': 480, 'resize': 'fit'},
#      'large': {'w': 640, 'h': 480, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 1334649486342320128,
#     'id_str': '1334649486342320128',
#     'indices': [195, 218],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1334649486342320128/pu/img/5wj6eDq3xU2uH99R.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1334649486342320128/pu/img/5wj6eDq3xU2uH99R.jpg',
#     'url': 'https://t.co/4TVMCFsoVn',
#     'display_url': 'pic.twitter.com/4TVMCFsoVn',
#     'expanded_url': 'https://twitter.com/mattdizwhitlock/status/1334649938932879363/video/1',
#     'type': 'video',
#     'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 640, 'h': 480, 'resize': 'fit'},
#      'large': {'w': 640, 'h': 480, 'resize': 'fit'}},
#     'video_info': {'aspect_ratio': [4, 3],
#      'duration_millis': 12101,
#      'variants': [{'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/ext_tw_video/1334649486342320128/pu/pl/d78isul7OKF87bVZ.m3u8?tag=10'},
#       {'bitrate': 256000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1334649486342320128/pu/vid/360x270/00Idk8ZCn8IzYLsJ.mp4?tag=10'},
#       {'bitrate': 2176000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1334649486342320128/pu/vid/640x480/baCVgNDSNi4FglUI.mp4?tag=10'},
#       {'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1334649486342320128/pu/vid/480x360/lzYfCIZN9GHWRTAS.mp4?tag=10'}]},
#     'additional_media_info': {'monetizable': False}}]},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 55192727,
#   'id_str': '55192727',
#   'name': 'Matt Whitlock',
#   'screen_name': 'mattdizwhitlock',
#   'location': 'Washington, DC',
#   'description': '@NRSC Senior Advisor. Former corporate comms and @SenOrrinHatch Comms/ Deputy COS. Bay Area born and raised. BYU grad. Tweets are my own.',
#   'url': 'https://t.co/5fqeeUJaNw',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/5fqeeUJaNw',
#       'expanded_url': 'http://nrsc.org',
#       'display_url': 'nrsc.org',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 47278,
#   'friends_count': 2180,
#   'listed_count': 360,
#   'created_at': 'Thu Jul 09 09:45:59 +0000 2009',
#   'favourites_count': 38237,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 35357,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '1A1B1F',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/818229110854057985/8jeedq3Q_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818229110854057985/8jeedq3Q_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/55192727/1586925294',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '120547',
#   'profile_text_color': 'F0F2F5',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 2582,
#  'favorite_count': 8448,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %% [markdown]
# Print the text of the tweet with more likes

# %%
more_likes = 0
text_with_more_likes = ""
for tweet in all_pages:
    json_data = tweet._json # get json 
    likes_tweet = json_data["favorite_count"] # get likes (named favourites in twitter)
    if likes_tweet > more_likes:
        more_likes = likes_tweet
        text_with_more_likes = json_data["full_text"]
        
print("Most liked tweet: {} with a total of {} likes.".format(text_with_more_likes,more_likes))
# Out:
# Most liked tweet: I WON THIS ELECTION, BY A LOT! with a total of 1196698 likes.

# %% [markdown]
# Print the text of the tweet with more retweets

# %%
more_retweets = 0
text_with_more_retweets = ""
for tweet in all_pages:
    json_data = tweet._json # get json 
    num_retweets = json_data["retweet_count"] # get likes (named favourites in twitter)
    if num_retweets > more_retweets:
        more_retweets = num_retweets
        text_with_more_retweets = json_data["full_text"]

print("Most retweeted tweet: {} with a total of {} retweets.".format(text_with_more_retweets,more_retweets))
# Out:
# Most retweeted tweet: I WON THIS ELECTION, BY A LOT! with a total of 192453 retweets.

# %% [markdown]
# # 4 Streaming API
#
# The Twitter API allows you to collect the public stream of Tweets, filtering them by topic. To do so, we need to set a "Listener", through Tweepy, in order to set some parameters like how much tweets to collect, how to store them, how to handle errors, etc...

# %%
class MyStreamListener(StreamListener):
    """
    Twitter listener, collects streaming tweets and output to a file
    """
    def __init__(self, api, OUTPUT_FILENAME, stop_condition=10):
        """
        initialize the stream, with num. of tweets and saving the outputfile
        """
        
        # this line is needed to import the characteristics of the streaming API
        super(MyStreamListener, self).__init__()
        
        # to-count the number of tweets collected        
        self.num_tweets = 0
        
        # save filename
        self.filename = OUTPUT_FILENAME
        
        # stop-condition
        self.stop_condition = stop_condition
        

    def on_status(self, status):
        
        """
        this function runs each time a new bunch of tweets is retrived from the streaming
        """
        
        with open(self.filename, "a+") as f:
            tweet = status._json
            f.write(json.dumps(tweet) + '\n')
            #self.output.append(tweet)
            self.num_tweets += 1
        
            # Stop condition        
            if self.num_tweets <= self.stop_condition:
                return True
            else:
                return False
        

    def on_error(self, status):
        """
        function useful to handle errors. It's possible to personalize it 
        depending on the way we want to handle errors
        """
        print(status)
        #returning False in on_error disconnects the stream
        return False

# %% [markdown]
# Let's analyze ```filter```, one of the crucial functions we run later. Running it we retrieve all the tweets having one of the substrings included in the list keywords.
#
# Here a brief summary for the options included in the function:
#
# - ```track``` put here the list of keywords you want to track. Pay attention that if you want to track hashtags you have to put the #, and for mentions @
#
# - ```is_async``` boolean that let you run in async the streaming. We strongly suggest to have it always ```False```
#
# - ```languages``` default ```None```. Twitter runs an automatic language detection algorithm, which in most of the cases can associated to the tweets the respective language (e.g. output ```"en"```, ```"it"```, ```"es"```, etc ..., ```"unk"``` for undetected ones). If you don't filter through this parameter, it will return tweets in any language.
#
# **Long story short:** If you think your topic is highly relevant only for a specific subgroup in twitter that talks only one language, then is better to avoid it. This is why the automatic detection doesn't have a 100% accuracy. Otherwise, it's strongly suggested. For *all* the topics listed in the project we strongly encourage you to filter tweets in English.
#
# For more details:
#
# https://developer.twitter.com/en/docs/twitter-api/v1/tweets/filter-realtime/guides/basic-stream-parameters

# %% [markdown]
# Here we download a bunch of tweets with a set of keywords related to covid ```["coronavirus", "covid"]```

# %%
# %%time

OUTPUT_FILENAME = "data/one.json"
stop_condition = 1000

l = MyStreamListener(api, OUTPUT_FILENAME, stop_condition)
# here we recall the Stream Class from Tweepy to input the authentication info and our personalized listener 
stream = Stream(auth=api.auth, listener=l)


# keywords we may want decide to track 
TRACKING_KEYWORDS = ["coronavirus", "covid", "#COVID", "#coronavirus", "#COVID19"]
stream.filter(
    track=TRACKING_KEYWORDS, 
    is_async=False, 
    languages = ["en"]
)
# Out:
# CPU times: user 532 ms, sys: 193 ms, total: 725 ms
# Wall time: 34.1 s

# %% [markdown]
# # 5. Let's analyze the json data
#
# **A. Statistical description of data**
#
# - how many retweets?
# - how many users?
# - how many unique tweets?
# - mostfrequent hashtags
#
# **B. Wordcloud**
# - wordcloud of hashtags
# - generate ```bag_of_words``` from tweets
# - wordcloud of text
#
# **C. Retweet graph**
#
# - build network of retweet
# - find nodes with highest in-degree
# - compute other nodes' centralities

# %% [markdown]
# ## A. Data structure

# %%
with open("data/one.json", "rb") as f:
    data = f.readlines()
    data = [json.loads(str_) for str_ in data]

# %%
df_tweets = pd.DataFrame.from_records(data)

# %%
len(df_tweets.text.unique())
# Out:
# 775

# %%
def print_retweets_uniqueTweets_uniqueUsers(df_tweets):
    retweets_ = df_tweets["retweeted_status"].apply(lambda x: 0 if str(x) == "nan" else 1) #list of o/1 for retweet or not
    tot_retweets = sum(retweets_)
    unique_tweets = len(retweets_) - tot_retweets
    
    users_ = df_tweets.user.apply(lambda x: x["id"])
    
    tot_users = len(set(users_))
    
    print("Tot Retweets")
    print(tot_retweets)

    print("Unique Tweets")
    print(unique_tweets)
    
    print("Unique Users")
    print(tot_users)

# %%
print_retweets_uniqueTweets_uniqueUsers(df_tweets)
# Out:
# Tot Retweets
# 597
# Unique Tweets
# 415
# Unique Users
# 988

# %%
def extract_hashtags():
    """
    
    """
    
    hashtags_lists = df_tweets["entities"].apply(lambda x: x["hashtags"])
    
    hashtags = hashtags_lists.apply(lambda x: x[0]["text"].lower() if x != [] else None)
    
    hashtags_by_frequency = Counter(hashtags)
    hashtags_by_frequency = {k: hashtags_by_frequency[k] for k in hashtags_by_frequency if k != None} 
    
    return hashtags_by_frequency

# %%
hashtags_lists = df_tweets["entities"].apply(lambda x: x["hashtags"])
hashtags_lists
# Out:
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
#                               ...
# 1007    [{'text': 'Leave', 'indices': [72, 78]}, {'tex...
# 1008    [{'text': 'Commodities', 'indices': [73, 85]},...
# 1009                                                   []
# 1010                                                   []
# 1011                                                   []
# Name: entities, Length: 1012, dtype: object

# %%
hashtags_by_frequency = extract_hashtags()
#hashtags_by_frequency

# %% [markdown]
# Let's plot the top-5 frequent hashtags now

# %%
df_hashtags = pd.DataFrame(hashtags_by_frequency.items())
df_hashtags.columns = ["hashtag", "count"]
df_hashtags.set_index("hashtag", inplace=True)
df_hashtags.sort_values("count", inplace=True, ascending=False)

# %%
df_hashtags.head(10).plot.barh()
plt.show()

# %% [markdown]
# Let's try now to generate a wordcloud given the tweets we have collected.

# %% [markdown]
# # B. Wordcloud

# %%
from wordcloud import WordCloud, ImageColorGenerator
import re

from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words("english"))

# %%
bag_of_words = {}
for text in df_tweets["text"]:
    
    # remove "RT" string indicating a retweet
    text = text.replace("RT ", "").strip()
    
    # lowering text
    text = text.lower()
    
    # removing all the punctuations
    text = re.sub(r'[^\w\s]','',text).strip()
    
    # tokenize the text
    lst_text = text.split()
    
    # remove stopwords
    lst_text = [x for x in lst_text if x not in STOPWORDS]
    
    for w in lst_text:
        if w not in bag_of_words:
            bag_of_words[w] = 0
        bag_of_words[w] +=1

# %%
def plot_wordcloud(title, dic_):
    fig, ax = plt.subplots(1, 1, figsize=(18,7))
    wordcloud = WordCloud(background_color="white",width=1600, height=800)
    wordcloud = wordcloud.generate_from_frequencies(dic_)
    ax.axis("off")     
    ax.imshow(wordcloud, interpolation='bilinear')

    ax.set_title(title)
    plt.tight_layout()
    fig.subplots_adjust(top=0.8)
    plt.show()

# %%
plot_wordcloud("WordCloud - All Tweets", bag_of_words)

# %% [markdown]
# ## C. Retweet graph

# %%
df_retweets = df_tweets[df_tweets["text"].apply(lambda x: x[:2]) == "RT"]

# %%
df_graph = pd.DataFrame(columns=["source", "destination"])

# add source-nodes
df_graph["source"] = df_retweets["user"].apply(lambda x: x["screen_name"])

# add destination-nodes
df_graph["destination"] = df_retweets["retweeted_status"].apply(lambda x: x["user"]["screen_name"])

# %%
df_graph.head()
# Out:
#            source      destination
# 0     o__ferreira       trapbrxzil
# 3       jinxiejae       donwinslow
# 6    DrMAMMohamed        coaimpaul
# 7   _berfindemir_  drfahrettinkoca
# 8  catch22forever        SoberLook

# %%
df_graph.drop_duplicates()
# Out:
#               source      destination
# 0        o__ferreira       trapbrxzil
# 3          jinxiejae       donwinslow
# 6       DrMAMMohamed        coaimpaul
# 7      _berfindemir_  drfahrettinkoca
# 8     catch22forever        SoberLook
# ...              ...              ...
# 1003        josxxx96           lxyyxn
# 1005   gombe__dopest   Gombe_BPoffice
# 1007    AliceSmart64      Anna_Soubry
# 1009    lotusflor122              ABC
# 1011    ladycatlover          IanDunt
#
# [590 rows x 2 columns]

# %% [markdown]
# We now analyze the retweet graph, given by user-user interactions. The graph G=(V,E) is generate, where V is the set of users and a generic edge (u,v) is created if user u retweeted a post of the user v.
#
# We look at nodes properties, such in-degree, closeness centrality and pagerank.
#
# A fast recap of the measures we're goin to use:
#
# - **closeness centrality**: *it is a measure of centrality in a network, calculated as the reciprocal of the sum of the length of the shortest paths between the node and all other nodes in the graph. Thus, the more central a node is, the closer it is to all other nodes* ([link](https://en.wikipedia.org/wiki/Closeness_centrality)).
#
# - **pagerank**: It defines a probability distribution over all the nodes in the graph. A score/probability assigned to each node indicates the importance of the single node, taking into account both local and global structure of the graph ([link](https://en.wikipedia.org/wiki/PageRank)).

# %%
import networkx as nx

# %%
G = nx.DiGraph()
G.add_edges_from(df_graph.values)
topk = 10

# %%
topk_indegree = sorted(G.in_degree(), key=lambda x: x[1], reverse=True)[:topk]

# %%
topk_indegree
# Out:
# [('IngrahamAngle', 13),
#  ('CNN', 12),
#  ('CortesSteve', 10),
#  ('ABC', 9),
#  ('AngrierWHStaff', 9),
#  ('JaniceDean', 8),
#  ('DFBHarvard', 8),
#  ('ikeeyah_', 8),
#  ('LeahR77', 7),
#  ('davidkurten', 7)]

# %%
topk_pagerank =  sorted(nx.pagerank(G).items(), key=lambda x: x[1], reverse=True)[:topk]

# %%
topk_pagerank
# Out:
# [('IngrahamAngle', 0.008002699019485433),
#  ('CNN', 0.007417567680222537),
#  ('CortesSteve', 0.006247305001696744),
#  ('ABC', 0.005954739332065296),
#  ('AngrierWHStaff', 0.005954739332065296),
#  ('JaniceDean', 0.0053696079928023995),
#  ('DFBHarvard', 0.0053696079928023995),
#  ('ikeeyah_', 0.0053696079928023995),
#  ('LeahR77', 0.004784476653539503),
#  ('davidkurten', 0.004784476653539503)]

# %%
topk_closeness = sorted(nx.closeness_centrality(G).items(), key=lambda x: x[1], reverse=True)[:topk]

# %%
topk_closeness
# Out:
# [('IngrahamAngle', 0.013785790031813362),
#  ('CNN', 0.012725344644750796),
#  ('CortesSteve', 0.010604453870625663),
#  ('ABC', 0.009544008483563097),
#  ('AngrierWHStaff', 0.009544008483563097),
#  ('JaniceDean', 0.008483563096500531),
#  ('DFBHarvard', 0.008483563096500531),
#  ('ikeeyah_', 0.008483563096500531),
#  ('LeahR77', 0.007423117709437964),
#  ('davidkurten', 0.007423117709437964)]
